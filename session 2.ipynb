# %%
#1.Create three variables in Python: user_name, fav_app, and daily_usage_hours. Assign your own name, your favorite app (like Instagram or Zomato), 
# and how many hours you use it daily.""


user_name = "Minal"
fav_app = "Instagram"
daily_usage_hours = 3

# %%
print(user_name)
print(fav_app)
print(daily_usage_hours)
# Out:
# Minal
# Instagram
# 3

# %%
""" 2.Write a Python script that declares variables for product_name, price,
and is_available to represent an item on Flipkart. Print each variable and its data type using the type() function. """


product_name = "Mobile phone"
price = 35000
is_available = True

# %%
print(product_name, type(product_name))
# Out:
# Mobile phone <class 'str'>

# %%
print(price, type(price))
# Out:
# 35000 <class 'int'>

# %%
print(is_available, type(is_available))
# Out:
# True <class 'bool'>

# %%
""" 3.Demonstrate the difference between single-line and multi-line comments in Python by writing a script that explains how a Spotify playlist recommendation system might work.
 Use for single-line and triple quotes for multi-line comments."""


# Spotify recommends songs based on user's listening history.

"""
Spotify Playlist Recommendation System

1. Collects user listening data.
2. Identifies favorite genres and artists.
3. Recommends similar songs and playlists.
4. Updates recommendations based on new activity.
"""
# Out:
# '\nSpotify Playlist Recommendation System\n\n1. Collects user listening data.\n2. Identifies favorite genres and artists.\n3. Recommends similar songs and playlists.\n4. Updates recommendations based on new activity.\n'

# %%
""" 4.Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order.Follow Python naming conventions and
 print a sentence using all three variables, like 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'"""


order_total = 1500
delivery_region = "Nikol"
discount_percent = 25

print(f"order from {delivery_region} total rupees {order_total} with {discount_percent} %  off ")
# Out:
# order from Nikol total rupees 1500 with 25 %  off

# %%
""" 5.Write a Python script that intentionally mixes tabs and spaces for indentation, then fix the script so it runs
without errors.<br><br><em><strong>Hint:</strong> Use only spaces for indentation, as per Python's best practices.</em>"""

if< xyz:

print(xyz)
# Out:
#   Cell In[4], line 4
#     if< xyz:
#       ^
# SyntaxError: invalid syntax
